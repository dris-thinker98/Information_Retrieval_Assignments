# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanishi20079/IR2021_A3_27/blob/main/Q2_partB_A3_IR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Wiki-Vote Dataset

# %%
import numpy as np
import networkx as nx

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
G = nx.read_edgelist('/content/drive/MyDrive/wiki-Vote.txt', comments='#', delimiter='\t', create_using=nx.DiGraph)
#number of nodes
len(G)
# Out:
# 7115

# %%
from networkx.drawing.layout import spring_layout

# %%
#nx.draw_networkx_nodes(G, spring_layout(G))

# %% [markdown]
# #PageRank Scores

# %%
#default damping factor of 0.85
prscores = nx.pagerank(G, max_iter = 100)

#Top to least PageRank Scores for each node
dict(sorted(prscores.items(), key=lambda item: item[1], reverse = True))
#prscores
# Out:
# {'4037': 0.0046127158911675485,
#  '15': 0.0036812207295292792,
#  '6634': 0.003524813657640259,
#  '2625': 0.0032863743692309023,
#  '2398': 0.0026053331717250192,
#  '2470': 0.0025301053283849546,
#  '2237': 0.002504703800483994,
#  '4191': 0.0022662633042363454,
#  '7553': 0.002170185049195958,
#  '5254': 0.0021500675059293235,
#  '1186': 0.0020438936876029153,
#  '2328': 0.0020416288860889186,
#  '1297': 0.0019518608216122285,
#  '4335': 0.0019353014475784877,
#  '7620': 0.0019301193957548752,
#  '5412': 0.00191670807752399,
#  '7632': 0.0019037739909136618,
#  '4875': 0.0018675748225119092,
#  '3352': 0.0017851250122027215,
#  '2654': 0.0017693207143482425,
#  '6832': 0.0017646895191923734,
#  '762': 0.0017478626294191988,
#  '6946': 0.0017404328450373553,
#  '737': 0.0017365555312247153,
#  '2066': 0.0017190133175865356,
#  '8293': 0.0017044691035007064,
#  '3089': 0.0016993720805897224,
#  '28': 0.0016986730322136937,
#  '2535': 0.0016682067978015206,
# ...

# %% [markdown]
# #Authority and Hub Scores

# %%
#Finding Authority and Hub scores using HITS algorithm
hubs, authorities = nx.hits(G, max_iter = 100, normalized = True)

# %% [markdown]
# Hub Scores for each node:

# %%
#Top to least Hub Score for each node
dict(sorted(hubs.items(), key=lambda item: item[1], reverse = True))
# Out:
# {'2565': 0.00794049270807403,
#  '766': 0.007574335297444512,
#  '2688': 0.006440248991012525,
#  '457': 0.00641687049019565,
#  '1166': 0.006010567902433343,
#  '1549': 0.0057207540583986485,
#  '11': 0.004921182064008282,
#  '1151': 0.004572040701802756,
#  '1374': 0.004467888792672376,
#  '1133': 0.003918881732047633,
#  '2485': 0.0037844608130809536,
#  '2972': 0.0035176739767459196,
#  '3449': 0.003503558110386082,
#  '3453': 0.003449414861030934,
#  '4967': 0.0034433407416886424,
#  '3352': 0.0033814231063793564,
#  '2871': 0.0032390167017806682,
#  '5524': 0.0031957811101465867,
#  '3642': 0.003156068703535115,
#  '1608': 0.0031218439182568183,
#  '2237': 0.003075961697014788,
#  '988': 0.00306413020584161,
#  '996': 0.0030115039739801275,
#  '2651': 0.0030035882462974292,
#  '789': 0.002971352114753837,
#  '68': 0.0029625234994343215,
#  '2967': 0.002941958558120979,
#  '3456': 0.0028914095712835176,
#  '5189': 0.0028753808634069686,
#  '2326': 0.0028390540913516317,
# ...

# %% [markdown]
# Authority scores for each node:

# %%
#Top to least Authorities score for each node
dict(sorted(authorities.items(), key=lambda item: item[1], reverse = True))
# Out:
# {'2398': 0.002580147178008918,
#  '4037': 0.002573241124142803,
#  '3352': 0.002328415091537902,
#  '1549': 0.0023037314804751075,
#  '762': 0.00225587485637424,
#  '3089': 0.0022534066884266454,
#  '1297': 0.00225014463679536,
#  '2565': 0.002223564103945871,
#  '15': 0.002201543492543811,
#  '2625': 0.0021978968035237852,
#  '2328': 0.0021723715454129585,
#  '2066': 0.0021070409397065445,
#  '4191': 0.0020811941305208825,
#  '3456': 0.002050435521490394,
#  '737': 0.002039382629304915,
#  '3537': 0.0019579567076096365,
#  '2576': 0.0019547902769057215,
#  '4712': 0.0018716357519817015,
#  '5412': 0.0018694113161459407,
#  '2535': 0.0018680659041328002,
#  '4335': 0.0018627007058849888,
#  '5254': 0.0018247396642980143,
#  '3897': 0.0017853121201428905,
#  '3334': 0.0017510881860138216,
#  '2516': 0.0017387561050193445,
#  '2654': 0.0017237094176338033,
#  '3117': 0.0017062491474186718,
#  '2653': 0.0016721359299613028,
#  '4099': 0.0016685048339351628,
# ...

# %%
#checking if scores are taken for all the nodes (each node)
print(len(prscores))
print(len(hubs))
print(len(authorities))
# Out:
# 7115
# 7115
# 7115
